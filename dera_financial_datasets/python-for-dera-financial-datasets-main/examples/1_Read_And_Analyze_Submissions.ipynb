# %% [markdown]
# <h1 align="center"> Read and Analyze Submissions Data Set</h1>
#
# ### Import Code Libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display, HTML
# Set the format for floating point numbers to show no decimal places
pd.set_option('display.float_format', lambda x: '%.0f' % x)
# To display plots inline within the notebook
# %matplotlib inline
# Set the notebook width to 100%
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Read 2022 Q1 Submission Data Set from [Financial Statement Data Sets](https://www.sec.gov/dera/data/financial-statement-data-sets) into a Pandas Data Frame named filingsQ1

# %%
# Setting low_memory parameter to False to prevent mixed type inference and default_na parameter to False so that empty strings are not parsed as NaN.
filingsQ1 = pd.read_csv('data/2022q1/sub.txt', sep='\t', low_memory=False, keep_default_na=False)

# %% [markdown]
# ### Look at the contents of filingsQ1 dataframe. We have 7,237 submissions. Each row has 36 columns.

# %%
filingsQ1
# Out:
#                       adsh      cik                               name   sic  \
# 0     0000002178-22-000033     2178     ADAMS RESOURCES & ENERGY, INC.  5172
# 1     0000002488-22-000016     2488         ADVANCED MICRO DEVICES INC  3674
# 2     0000002969-22-000010     2969  AIR PRODUCTS & CHEMICALS INC /DE/  2810
# 3     0000003499-22-000004     3499                     ALEXANDERS INC  6798
# 4     0000003570-22-000024     3570                CHENIERE ENERGY INC  4924
# ...                    ...      ...                                ...   ...
# 7232  0001902733-22-000013  1902733                        NCINO, INC.  7372
# 7233  0001903596-22-000067  1853825                 THUMZUP MEDIA CORP  7374
# 7234  0001903596-22-000075  1414767                    NETCAPITAL INC.  6199
# 7235  0001903596-22-000108  1087022              ALR TECHNOLOGIES INC.  3669
# 7236  0001903596-22-000131  1163389         NEW PEOPLES BANKSHARES INC  6022
#
# ...

# %% [markdown]
# ### To view the contents of first two rows of filingsQ1 Data Frame

# %%
filingsQ1.head(2)
# Out:
#                    adsh   cik                            name   sic countryba  \
# 0  0000002178-22-000033  2178  ADAMS RESOURCES & ENERGY, INC.  5172        US
# 1  0000002488-22-000016  2488      ADVANCED MICRO DEVICES INC  3674        US
#
#   stprba       cityba  zipba                    bas1 bas2  ...    period  \
# 0     TX      HOUSTON  77027  17 S. BRIAR HOLLOW LN.       ...  20211231
# 1     CA  SANTA CLARA  95054    2485 AUGUSTINE DRIVE       ...  20211231
#
#      fy  fp     filed               accepted prevrpt detail  \
# 0  2021  FY  20220309  2022-03-09 16:17:00.0       0      1
# 1  2021  FY  20220203  2022-02-03 17:23:00.0       0      1
#
#                instance nciks aciks
# 0   ae-20211231_htm.xml     1
# 1  amd-20211225_htm.xml     1
#
# [2 rows x 36 columns]

# %% [markdown]
# ### To view the contents of last three rows of filingsQ1 Data Frame, use head function

# %%
filingsQ1.tail(3)
# Out:
#                       adsh      cik                        name   sic  \
# 7234  0001903596-22-000075  1414767             NETCAPITAL INC.  6199
# 7235  0001903596-22-000108  1087022       ALR TECHNOLOGIES INC.  3669
# 7236  0001903596-22-000131  1163389  NEW PEOPLES BANKSHARES INC  6022
#
#      countryba stprba    cityba  zipba                         bas1  \
# 7234        US     MA    BOSTON  02111             1 LINCOLN STREET
# 7235        US     VA  RICHMOND  23225  7400 BEAUFONT SPRINGS DRIVE
# 7236        US     VA   HONAKER  24260            67 COMMERCE DRIVE
#
#            bas2  ...    period    fy  fp     filed               accepted  \
# 7234             ...  20220131  2022  Q3  20220318  2022-03-18 13:00:00.0
# 7235  SUITE 300  ...  20211231  2021  FY  20220330  2022-03-30 13:01:00.0
# 7236             ...  20211231  2021  FY  20220331  2022-03-31 17:16:00.0
#
#      prevrpt detail                  instance nciks aciks
# ...

# %% [markdown]
# ### To view specific rows of filingsQ1 Data Frame, use tail function

# %%
filingsQ1[100:102]
# Out:
#                      adsh    cik                        name   sic countryba  \
# 100  0000038777-22-000013  38777      FRANKLIN RESOURCES INC  6282        US
# 101  0000039263-22-000008  39263  CULLEN/FROST BANKERS, INC.  6021        US
#
#     stprba       cityba  zipba                  bas1  \
# 100     CA    SAN MATEO  94403  ONE FRANKLIN PARKWAY
# 101     TX  SAN ANTONIO  78205      111 W HOUSTON ST
#
#                                     bas2  ...    period    fy  fp     filed  \
# 100  BUILDING 920/2, LEGAL-FRI SECRETARY  ...  20211231  2022  Q1  20220201
# 101                                       ...  20211231  2021  FY  20220204
#
#                   accepted prevrpt detail              instance nciks aciks
# 100  2022-02-01 08:45:00.0       0      1  ben-20211231_htm.xml     1
# 101  2022-02-04 15:55:00.0       0      1  cfr-20211231_htm.xml     1
#
# [2 rows x 36 columns]

# %% [markdown]
# ### List All Column Names of the DataFrame

# %%
filingsQ1.columns
# Out:
# Index(['adsh', 'cik', 'name', 'sic', 'countryba', 'stprba', 'cityba', 'zipba',
#        'bas1', 'bas2', 'baph', 'countryma', 'stprma', 'cityma', 'zipma',
#        'mas1', 'mas2', 'countryinc', 'stprinc', 'ein', 'former', 'changed',
#        'afs', 'wksi', 'fye', 'form', 'period', 'fy', 'fp', 'filed', 'accepted',
#        'prevrpt', 'detail', 'instance', 'nciks', 'aciks'],
#       dtype='object')

# %% [markdown]
# ### Create a New DataFrame with a Subset of Columns

# %%
subsetDF = filingsQ1[['name', 'countryinc', 'afs', 'form', 'period', 'fy', 'fp', 'filed']]
subsetDF
# Out:
#                                    name countryinc    afs    form    period  \
# 0        ADAMS RESOURCES & ENERGY, INC.         US  4-NON    10-K  20211231
# 1            ADVANCED MICRO DEVICES INC         US  1-LAF    10-K  20211231
# 2     AIR PRODUCTS & CHEMICALS INC /DE/         US  1-LAF    10-Q  20211231
# 3                        ALEXANDERS INC         US  2-ACC    10-K  20211231
# 4                   CHENIERE ENERGY INC         US  1-LAF    10-K  20211231
# ...                                 ...        ...    ...     ...       ...
# 7232                        NCINO, INC.         US  1-LAF    10-K  20220131
# 7233                 THUMZUP MEDIA CORP         US  4-NON    10-K  20211231
# 7234                    NETCAPITAL INC.         US  4-NON  10-Q/A  20220131
# 7235              ALR TECHNOLOGIES INC.         US  4-NON    10-K  20211231
# 7236         NEW PEOPLES BANKSHARES INC         US  4-NON    10-K  20211231
#
#         fy  fp     filed
# 0     2021  FY  20220309
# ...

# %% [markdown]
# ### Print DataFrame Information including Data Types, Count of Non-null Values and Memory Usage

# %%
subsetDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7237 entries, 0 to 7236
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        7237 non-null   object
#  1   countryinc  7237 non-null   object
#  2   afs         7237 non-null   object
#  3   form        7237 non-null   object
#  4   period      7237 non-null   int64
#  5   fy          7237 non-null   object
#  6   fp          7237 non-null   object
#  7   filed       7237 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 452.4+ KB

# %% [markdown]
# ### Generate Descriptive Statistics

# %%
subsetDF.describe().transpose()
# Out:
#         count     mean  std      min      25%      50%      75%      max
# period   7237 20211452 2392 20160930 20211231 20211231 20211231 20220228
# filed    7237 20220262   65 20220103 20220217 20220301 20220318 20220331

# %% [markdown]
# ### Find Unique Values of countryinc Column

# %%
subsetDF.countryinc.unique()
# Out:
# array(['US', 'CA', '', 'IE', 'GB', 'NL', 'BM', 'ES', 'SG', 'CH', 'MH',
#        'JE', 'KY', 'IL', 'VG', 'PR', 'SE', 'JP', 'DE', 'LU', 'FR', 'BE',
#        'DK', 'BR', 'NO', 'GG', 'AU', 'CN', 'AN', 'IO', 'AI', 'MY', 'VI',
#        'FI', 'MX', 'MU', 'BS', 'GU', 'ZA'], dtype=object)

# %% [markdown]
# ### Filter for Candian Filers

# %%
subsetDF[subsetDF.countryinc == 'CA']
# Out:
#                               name countryinc    afs  form    period    fy  \
# 41    CANADIAN NATIONAL RAILWAY CO         CA          6-K  20211231  2021
# 464                VISTA GOLD CORP         CA  4-NON  10-K  20211231  2021
# 493              NEW GOLD INC. /FI         CA         40-F  20211231  2021
# 633    INTERTAPE POLYMER GROUP INC         CA  1-LAF  20-F  20211231  2021
# 658             TECK RESOURCES LTD         CA         40-F  20211231  2021
# ...                            ...        ...    ...   ...       ...   ...
# 6991     BROOKFIELD RENEWABLE CORP         CA  1-LAF  20-F  20211231  2021
# 7051   CLEVER LEAVES HOLDINGS INC.         CA  4-NON  10-K  20211231  2021
# 7098      MEDMEN ENTERPRISES, INC.         CA  4-NON  10-Q  20211231  2022
# 7114      MEDMEN ENTERPRISES, INC.         CA  4-NON   S-1  20211231
# 7144            CI FINANCIAL CORP.         CA         40-F  20211231  2021
#
#       fp     filed
# 41    FY  20220201
# 464   FY  20220224
# ...

# %% [markdown]
# ### Group Submissions By Form Column and Compute Group Sizes

# %%
formGroupBy = subsetDF.groupby('form')
formGroups = formGroupBy.size().reset_index(name='count')
# Sort the results by count
formGroups = formGroups.sort_values(by = ['count'])
formGroups
# Out:
#         form  count
# 19     F-3/A      1
# 5    10-KT/A      1
# 26    S-11/A      2
# 25      S-11      2
# 15       8-K      2
# 0     10-12G      3
# 12    40-F/A      3
# 14     6-K/A      3
# 8      10-QT      5
# 21     F-4/A      5
# 20       F-4      5
# 17       F-1      5
# 18     F-1/A      5
# 1   10-12G/A      7
# 16     8-K/A      8
# 10    20-F/A     11
# 4      10-KT     14
# 27       S-4     30
# 28     S-4/A     35
# 13       6-K     43
# 23       S-1     92
# 22    POS AM     93
# 24     S-1/A    102
# 3     10-K/A    105
# 11      40-F    120
# 7     10-Q/A    257
# 9       20-F    287
# 6       10-Q   1129
# 2       10-K   4862

# %% [markdown]
# #### Filter Submissions for Important Forms (Form 10-K for Annual Filings, Form 10-Q for Quarterly Filings, Form 20-F and 40-F for Foreign Private Issuers)

# %%
importantForms = ['10-K', '10-K/A', '10-Q', '10-Q/A', '20-F', '20-F/A', '40-F', '40-F/A']
filter = formGroups['form'].isin(importantForms)
importantFormGroups = formGroups[filter]
importantFormGroups
# Out:
#       form  count
# 12  40-F/A      3
# 10  20-F/A     11
# 3   10-K/A    105
# 11    40-F    120
# 7   10-Q/A    257
# 9     20-F    287
# 6     10-Q   1129
# 2     10-K   4862

# %% [markdown]
# ### Visualize Statistics for Important Forms using Pyplot Library

# %%
# Create a bar chart with form type on x axis and counts on y axis
importantFormGroups.plot(x='form', y='count', kind='bar', figsize=(8,6))
# Set title and labels for x & y axes
plt.title('Structured Data Form Statistics for 2022 Q1',fontsize=15)
plt.xlabel('Form Type', fontsize=15)
plt.ylabel('Number of Filings', fontsize=15)
plt.yticks(np.arange(0, 5001, step=500))
plt.xticks(rotation=0)
# Save the bar chart as a file in images folder
plt.savefig('images/FormStats2022Q1.jpg')
plt.show()
